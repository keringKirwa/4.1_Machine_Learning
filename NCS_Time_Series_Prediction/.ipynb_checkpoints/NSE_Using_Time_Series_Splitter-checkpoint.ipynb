# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.models import Sequential
from keras.layers import LSTM, Dense, Input, InputLayer, Dropout

import pandas as pd
import numpy as np

np.random.seed(42)

import os
import tensorflow as tf

from keras.utils import plot_model

#DATA NORMALIZATION(STANDARDISATION)
from sklearn.preprocessing import MinMaxScaler

#DATA PLOTTING
import matplotlib.pyplot as plt

#FOR PERFORMANCE METRICS ANALYSIS.
from keras.optimizers import Adam
from keras.losses import  MeanSquaredError
from keras.metrics import  RootMeanSquaredError

#SAVING AND LOADING MODEL
from keras.callbacks import ModelCheckpoint, History
from keras.models import load_model
# Out:
# 2023-11-07 11:10:31.351055: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-07 11:10:31.408969: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-07 11:10:31.409011: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-07 11:10:31.409053: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-07 11:10:31.418186: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-07 11:10:31.419223: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-07 11:10:32.896148: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
nsc_data_frame = pd.read_csv("NSE_data_all_stocks_2022_jan_to_may (1).csv")
nsc_data_frame
# Out:
#            Date  Code                        Name   12m Low  12m High  \
# 0      3-Jan-22  EGAD                 Eaagads Ltd        10        15
# 1      3-Jan-22  KUKZ                  Kakuzi Plc       355       427
# 2      3-Jan-22  KAPC     Kapchorua Tea Kenya Plc        80       101
# 3      3-Jan-22  LIMT              Limuru Tea Plc       260       360
# 4      3-Jan-22  SASN                  Sasini Plc     16.75      22.6
# ...         ...   ...                         ...       ...       ...
# 6727  31-May-22   MSC    Mumias Sugar Company Ltd      0.27      0.27
# 6728  31-May-22  UNGA              Unga Group Ltd      26.1      36.4
# 6729  31-May-22  SCOM               Safaricom Plc      25.5     45.25
# 6730  31-May-22  FAHR  Stanlib Fahari Income-REIT         5      7.48
# 6731  31-May-22   GLD            ABSA NewGold ETF  1,780.00  2,135.00
#
#        Day Low  Day High Day Price  Previous Change Change%      Volume  \
# 0         13.5      13.8      13.5      13.5      -       -       4,000
# 1          385       385       385       385      -       -           -
# 2         99.5      99.5      99.5      95.5      4   4.19%         100
# 3          320       320       320       320      -       -           -
# 4         18.7      18.7      18.7      18.7      -       -           -
# ...        ...       ...       ...       ...    ...     ...         ...
# 6727      0.27      0.27      0.27      0.27      -       -           -
# 6728        29        29        29        30     -1   3.33%       2,100
# 6729     25.95     26.45        26     26.25  -0.25   0.95%  20,079,900
# 6730       5.5       5.6      5.56      5.58  -0.02   0.36%      11,700
# 6731  2,135.00  2,135.00  2,135.00  2,135.00      -       -           -
#
#      Adjusted Price
# 0                 -
# 1                 -
# 2                 -
# 3                 -
# 4                 -
# ...             ...
# 6727              -
# 6728              -
# 6729              -
# 6730              -
# 6731              -
#
# [6732 rows x 13 columns]

# %%
#DATA  CLEANING  # nsc_data_frame.set_index(nsc_data_frame.Date, inplace=True) to update the index  of the dataframe.

date_format = '%d-%b-%y'
nsc_data_frame.Date = pd.to_datetime(nsc_data_frame['Date'], format=date_format)

nsc_data_frame['Day_Name'] = nsc_data_frame['Date'].dt.day_name()

nsc_data_frame = nsc_data_frame.drop(columns=['Change', 'Change%', 'Volume', 'Adjusted Price'])

# %%
# min_value = egad_data_frame['Day_Of_The_Week'].min()  ------ >> display(egad_data_frame.info())

# SELECT THE 2ND COLUMN AND PLOT THE DAY PRICE AGAINST TIME

plt.subplot(1, 2, 2)  
price_column = pd.to_numeric(nsc_data_frame['Day Price'], errors='coerce')
price_column[:50].plot()
plt.title('Day Price Over Time')

plt.tight_layout()  # To improve subplot spacing
plt.show()

# preprocessed_df['Date'] =pd.to_datetime(preprocessed_df['Date'])  plt.plot(preprocessed_df['Date'], preprocessed_df['Day Price'])

# %%
#Custom Data cleaner 
import random
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import pandas as pd

nsc_scaler = StandardScaler()

class NSCDataPreProcessor(BaseEstimator, TransformerMixin):
    
    def __init__(self,company_code ,to_type_cast, to_scale, to_return):
        self.company_code = company_code        
        self.to_type_cast= to_type_cast 
        self.to_return= to_return 
        self.to_scale=to_scale  #same as  columns_to_type_cast but has the company code.
        
        
    def __type_cast_and_scale_xyz_df(self, xyz_data_frame):
        for column_name in self.to_type_cast:
            xyz_data_frame[column_name] = pd.to_numeric(xyz_data_frame[column_name], errors='coerce')
        xyz_data_frame[self.to_scale] = nsc_scaler.fit_transform(xyz_data_frame[self.to_scale])
        
        
        return xyz_data_frame[self.to_return]
    
    def fit(self, X, y=None):
        return self
       

    def transform(self, X):   
        """
        X - NSC dataFrame
        Selects the data for one company , then names it xyz_company_data_frame 
        NB: Scaler always return columns that are assignable to the dataframe.        
        """        
        
        xyz_company_data_frame = nsc_data_frame[nsc_data_frame['Code'] == self.company_code].reset_index(drop=True)
        type_converted_xyz_company_df = self.__type_cast_and_scale_xyz_df(
            xyz_company_data_frame       
        )
        
        return type_converted_xyz_company_df
    
# 'Code','Day Price','Day High', 'Day High', '12m High', '12m Low' , 'Day Price','Day High', 'Day High', '12m High', '12m Low'

random_company_code = random.choice(nsc_data_frame.Code)
    
__data_scaler = NSCDataPreProcessor(
    company_code= random_company_code,
    to_type_cast=['Day Price','Day High', 'Day Low', '12m High', '12m Low'],
    to_scale=[ 'Previous','Day High', 'Day Low', '12m High', '12m Low'],
    to_return=['Code','Day Price','Previous','Day High', 'Day Low', '12m High', '12m Low'], 
)

xyz_preprocessed_df = __data_scaler.fit_transform(
    nsc_data_frame,    
)
display(xyz_preprocessed_df)

preprocessed_df = xyz_preprocessed_df.drop(columns=['Code'])
preprocessed_df
# Out:
#      Code  Day Price  Previous  Day High   Day Low  12m High  12m Low
# 0    SLAM      11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 1    SLAM      11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 2    SLAM      11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 3    SLAM      11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 4    SLAM      11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# ..    ...        ...       ...       ...       ...       ...      ...
# 97   SLAM      14.00  1.740602  1.171321  1.247340       0.0      0.0
# 98   SLAM      14.00  1.236240  1.171321  1.247340       0.0      0.0
# 99   SLAM      14.00  1.236240  1.171321  1.247340       0.0      0.0
# 100  SLAM      14.00  1.236240  1.171321  1.247340       0.0      0.0
# 101  SLAM      14.00  1.236240  1.171321  1.247340       0.0      0.0
#
# [102 rows x 7 columns]
#      Day Price  Previous  Day High   Day Low  12m High  12m Low
# 0        11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 1        11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 2        11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 3        11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# 4        11.55 -0.217510 -0.267002 -0.192962       0.0      0.0
# ..         ...       ...       ...       ...       ...      ...
# 97       14.00  1.740602  1.171321  1.247340       0.0      0.0
# 98       14.00  1.236240  1.171321  1.247340       0.0      0.0
# 99       14.00  1.236240  1.171321  1.247340       0.0      0.0
# 100      14.00  1.236240  1.171321  1.247340       0.0      0.0
# 101      14.00  1.236240  1.171321  1.247340       0.0      0.0
#
# [102 rows x 6 columns]

# %%
output_var = pd.DataFrame(preprocessed_df['Day Price'])
features = ['Previous','Day High', 'Day Low', '12m High', '12m Low']

feature_transform =  preprocessed_df[features]
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=preprocessed_df.index)
display(output_var)
feature_transform
# Out:
#      Day Price
# 0        11.55
# 1        11.55
# 2        11.55
# 3        11.55
# 4        11.55
# ..         ...
# 97       14.00
# 98       14.00
# 99       14.00
# 100      14.00
# 101      14.00
#
# [102 rows x 1 columns]
#      Previous  Day High   Day Low  12m High  12m Low
# 0   -0.217510 -0.267002 -0.192962       0.0      0.0
# 1   -0.217510 -0.267002 -0.192962       0.0      0.0
# 2   -0.217510 -0.267002 -0.192962       0.0      0.0
# 3   -0.217510 -0.267002 -0.192962       0.0      0.0
# 4   -0.217510 -0.267002 -0.192962       0.0      0.0
# ..        ...       ...       ...       ...      ...
# 97   1.740602  1.171321  1.247340       0.0      0.0
# 98   1.236240  1.171321  1.247340       0.0      0.0
# 99   1.236240  1.171321  1.247340       0.0      0.0
# 100  1.236240  1.171321  1.247340       0.0      0.0
# 101  1.236240  1.171321  1.247340       0.0      0.0
#
# [102 rows x 5 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit
time_series_split= TimeSeriesSplit(n_splits=10) #number of splits to be 10, indicating that 10% of the data will serve as the test set


for train_index, test_index in time_series_split.split(feature_transform):
        X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])
input_shape = (X_train.shape[1],X_train.shape[2])
input_shape
# Out:
# (1, 5)

# %%
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV , TimeSeriesSplit
from sklearn.base import BaseEstimator, RegressorMixin

# %%
class KerasLSTMRegressor(BaseEstimator, RegressorMixin):
    def __init__(self, activation='relu', dropout_rate=0.2, num_units=100, learning_rate=0.001, epochs=10, batch_size=32):
        self.activation = activation
        self.dropout_rate = dropout_rate
        self.num_units = num_units
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size

    def create_lstm_model(self):
        model = Sequential()
        model.add(LSTM(self.num_units, input_shape=input_shape, activation=self.activation, return_sequences=True))
        model.add(Dropout(self.dropout_rate))
        model.add(LSTM(self.num_units, activation=self.activation, return_sequences=False))
        model.add(Dropout(self.dropout_rate))
        model.add(Dense(1))

        optimizer = Adam(learning_rate=self.learning_rate)

        model.compile(loss=MeanSquaredError(), optimizer=optimizer, metrics=[RootMeanSquaredError()])

        return model

    def fit(self, X, y):
        self.model = self.create_lstm_model()
        self.model.fit(X, y, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
        return self

    def predict(self, X):
        return self.model.predict(X)

    def score(self, X, y):
        predictions = self.predict(X)
        return -np.mean((y - predictions) ** 2)  # We negate the results since GridSearchCV seeks to maximize it

param_grid = {
    'activation': ['relu', 'tanh'],
    'dropout_rate': [0.1, 0.2, 0.3],
    'num_units': [50,100, 150,200],
    'learning_rate': [0.1, 0.001, 0.0001]
}

n_splits = 5  
time_series_split = TimeSeriesSplit(n_splits=n_splits)

custom_estimator = KerasLSTMRegressor()
grid = GridSearchCV(estimator=custom_estimator, param_grid=param_grid, cv=time_series_split, verbose=1, scoring='neg_mean_squared_error')

# grid  = RandomizedSearchCV(estimator=custom_estimator, param_distributions=param_grid, n_iter=10, cv=time_series_split, verbose=1, scoring='neg_mean_squared_error', random_state=42)

grid_result = grid.fit(X_train, y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 474ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 446ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 1s 500ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 448ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 446ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 1s 517ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 446ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 0s 450ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 375ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 491ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 1s 946ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step

# %%
def create_NSC_LSTM_model(activation='tanh', dropout_rate=0.2, num_units=150, learning_rate=0.1):
    model = Sequential()
    model.add(LSTM(num_units, input_shape=input_shape, activation=activation, return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(num_units, activation=activation, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1))

    optimizer = Adam(learning_rate=learning_rate)

    model.compile(loss=MeanSquaredError(), optimizer=optimizer, metrics=[RootMeanSquaredError()])

    return model

lstm = create_NSC_LSTM_model()

# %%
history=lstm.fit(X_train, y_train, epochs=200, batch_size=8, verbose=1, shuffle=False)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 5s 9ms/step - loss: 68.7233 - root_mean_squared_error: 8.2899
# Epoch 2/200
# 12/12 [==============================] - 0s 10ms/step - loss: 16.8714 - root_mean_squared_error: 4.1075
# Epoch 3/200
# 12/12 [==============================] - 0s 10ms/step - loss: 6.3341 - root_mean_squared_error: 2.5168
# Epoch 4/200
# 12/12 [==============================] - 0s 10ms/step - loss: 3.4837 - root_mean_squared_error: 1.8665
# Epoch 5/200
# 12/12 [==============================] - 0s 11ms/step - loss: 2.7306 - root_mean_squared_error: 1.6525
# Epoch 6/200
# 12/12 [==============================] - 0s 10ms/step - loss: 3.8095 - root_mean_squared_error: 1.9518
# Epoch 7/200
# 12/12 [==============================] - 0s 9ms/step - loss: 4.1828 - root_mean_squared_error: 2.0452
# Epoch 8/200
# 12/12 [==============================] - 0s 8ms/step - loss: 3.7839 - root_mean_squared_error: 1.9452
# Epoch 9/200
# 12/12 [==============================] - 0s 9ms/step - loss: 5.1032 - root_mean_squared_error: 2.2590
# Epoch 10/200
# 12/12 [==============================] - 0s 9ms/step - loss: 7.4510 - root_mean_squared_error: 2.7297
# Epoch 11/200
# 12/12 [==============================] - 0s 9ms/step - loss: 8.8499 - root_mean_squared_error: 2.9749
# Epoch 12/200
# 12/12 [==============================] - 0s 9ms/step - loss: 9.8281 - root_mean_squared_error: 3.1350
# Epoch 13/200
# 12/12 [==============================] - 0s 12ms/step - loss: 8.2994 - root_mean_squared_error: 2.8809
# Epoch 14/200
# 12/12 [==============================] - 0s 9ms/step - loss: 5.5625 - root_mean_squared_error: 2.3585
# Epoch 15/200
# 12/12 [==============================] - 0s 9ms/step - loss: 3.4832 - root_mean_squared_error: 1.8663
# Epoch 16/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.8725 - root_mean_squared_error: 1.3684
# Epoch 17/200
# 12/12 [==============================] - 0s 10ms/step - loss: 2.3117 - root_mean_squared_error: 1.5204
# Epoch 18/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.1254 - root_mean_squared_error: 1.4579
# Epoch 19/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3426 - root_mean_squared_error: 1.1587
# Epoch 20/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9640 - root_mean_squared_error: 0.9818
# Epoch 21/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.8250 - root_mean_squared_error: 1.3509
# Epoch 22/200
# 12/12 [==============================] - 0s 9ms/step - loss: 3.0588 - root_mean_squared_error: 1.7489
# Epoch 23/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.5192 - root_mean_squared_error: 1.5872
# Epoch 24/200
# 12/12 [==============================] - 0s 10ms/step - loss: 2.5060 - root_mean_squared_error: 1.5830
# Epoch 25/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9129 - root_mean_squared_error: 1.3831
# Epoch 26/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.9389 - root_mean_squared_error: 1.3925
# Epoch 27/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0400 - root_mean_squared_error: 1.0198
# Epoch 28/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9738 - root_mean_squared_error: 1.4049
# Epoch 29/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4386 - root_mean_squared_error: 1.1994
# Epoch 30/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.4290 - root_mean_squared_error: 1.1954
# Epoch 31/200
# 12/12 [==============================] - 0s 10ms/step - loss: 5.2616 - root_mean_squared_error: 2.2938
# Epoch 32/200
# 12/12 [==============================] - 0s 8ms/step - loss: 7.2854 - root_mean_squared_error: 2.6991
# Epoch 33/200
# 12/12 [==============================] - 0s 9ms/step - loss: 6.3372 - root_mean_squared_error: 2.5174
# Epoch 34/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9359 - root_mean_squared_error: 1.7134
# Epoch 35/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.5038 - root_mean_squared_error: 1.2263
# Epoch 36/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.9581 - root_mean_squared_error: 1.3993
# Epoch 37/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7578 - root_mean_squared_error: 1.3258
# Epoch 38/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.8867 - root_mean_squared_error: 1.6990
# Epoch 39/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9065 - root_mean_squared_error: 1.3808
# Epoch 40/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.5510 - root_mean_squared_error: 1.2454
# Epoch 41/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.1946 - root_mean_squared_error: 1.0930
# Epoch 42/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.5195 - root_mean_squared_error: 1.2327
# Epoch 43/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3661 - root_mean_squared_error: 1.1688
# Epoch 44/200
# 12/12 [==============================] - 0s 10ms/step - loss: 3.0081 - root_mean_squared_error: 1.7344
# Epoch 45/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.7268 - root_mean_squared_error: 1.3141
# Epoch 46/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.1086 - root_mean_squared_error: 1.0529
# Epoch 47/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.5559 - root_mean_squared_error: 1.2474
# Epoch 48/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3631 - root_mean_squared_error: 1.1675
# Epoch 49/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.6131 - root_mean_squared_error: 1.2701
# Epoch 50/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2758 - root_mean_squared_error: 1.1295
# Epoch 51/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.1869 - root_mean_squared_error: 1.0894
# Epoch 52/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8565 - root_mean_squared_error: 0.9255
# Epoch 53/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7962 - root_mean_squared_error: 0.8923
# Epoch 54/200
# 12/12 [==============================] - 0s 11ms/step - loss: 1.5930 - root_mean_squared_error: 1.2622
# Epoch 55/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.9758 - root_mean_squared_error: 0.9878
# Epoch 56/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6457 - root_mean_squared_error: 1.2828
# Epoch 57/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.7345 - root_mean_squared_error: 1.3170
# Epoch 58/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.6382 - root_mean_squared_error: 1.6243
# Epoch 59/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.7129 - root_mean_squared_error: 1.3088
# Epoch 60/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6388 - root_mean_squared_error: 1.2801
# Epoch 61/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.2479 - root_mean_squared_error: 1.4993
# Epoch 62/200
# 12/12 [==============================] - 0s 10ms/step - loss: 3.2487 - root_mean_squared_error: 1.8024
# Epoch 63/200
# 12/12 [==============================] - 0s 11ms/step - loss: 1.9048 - root_mean_squared_error: 1.3802
# Epoch 64/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2790 - root_mean_squared_error: 1.1309
# Epoch 65/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1229 - root_mean_squared_error: 1.0597
# Epoch 66/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2686 - root_mean_squared_error: 1.1263
# Epoch 67/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2674 - root_mean_squared_error: 1.1258
# Epoch 68/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.0246 - root_mean_squared_error: 1.0122
# Epoch 69/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0108 - root_mean_squared_error: 1.0054
# Epoch 70/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.6900 - root_mean_squared_error: 1.3000
# Epoch 71/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.5901 - root_mean_squared_error: 1.6094
# Epoch 72/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.2898 - root_mean_squared_error: 1.5132
# Epoch 73/200
# 12/12 [==============================] - 0s 9ms/step - loss: 6.4429 - root_mean_squared_error: 2.5383
# Epoch 74/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.4045 - root_mean_squared_error: 1.5506
# Epoch 75/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9007 - root_mean_squared_error: 1.3787
# Epoch 76/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3362 - root_mean_squared_error: 1.5285
# Epoch 77/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.5899 - root_mean_squared_error: 1.2609
# Epoch 78/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.0132 - root_mean_squared_error: 1.0066
# Epoch 79/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1854 - root_mean_squared_error: 1.0888
# Epoch 80/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9040 - root_mean_squared_error: 0.9508
# Epoch 81/200
# 12/12 [==============================] - 0s 10ms/step - loss: 2.0024 - root_mean_squared_error: 1.4151
# Epoch 82/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.5733 - root_mean_squared_error: 1.2543
# Epoch 83/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3608 - root_mean_squared_error: 1.1665
# Epoch 84/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1460 - root_mean_squared_error: 1.0705
# Epoch 85/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3798 - root_mean_squared_error: 1.1746
# Epoch 86/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0199 - root_mean_squared_error: 1.0099
# Epoch 87/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8394 - root_mean_squared_error: 0.9162
# Epoch 88/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7606 - root_mean_squared_error: 0.8721
# Epoch 89/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5847 - root_mean_squared_error: 0.7647
# Epoch 90/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7705 - root_mean_squared_error: 0.8778
# Epoch 91/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6885 - root_mean_squared_error: 0.8297
# Epoch 92/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9453 - root_mean_squared_error: 0.9722
# Epoch 93/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8353 - root_mean_squared_error: 0.9139
# Epoch 94/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8266 - root_mean_squared_error: 0.9092
# Epoch 95/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.4071 - root_mean_squared_error: 1.1862
# Epoch 96/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0943 - root_mean_squared_error: 1.0461
# Epoch 97/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2837 - root_mean_squared_error: 1.1330
# Epoch 98/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0584 - root_mean_squared_error: 1.0288
# Epoch 99/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8405 - root_mean_squared_error: 0.9168
# Epoch 100/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0367 - root_mean_squared_error: 1.0182
# Epoch 101/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7763 - root_mean_squared_error: 0.8811
# Epoch 102/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0067 - root_mean_squared_error: 1.0033
# Epoch 103/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9621 - root_mean_squared_error: 0.9808
# Epoch 104/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3551 - root_mean_squared_error: 1.1641
# Epoch 105/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2442 - root_mean_squared_error: 1.1154
# Epoch 106/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0676 - root_mean_squared_error: 1.0333
# Epoch 107/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6935 - root_mean_squared_error: 0.8328
# Epoch 108/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8178 - root_mean_squared_error: 0.9043
# Epoch 109/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7710 - root_mean_squared_error: 0.8781
# Epoch 110/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9103 - root_mean_squared_error: 0.9541
# Epoch 111/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3869 - root_mean_squared_error: 1.1777
# Epoch 112/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0078 - root_mean_squared_error: 1.0039
# Epoch 113/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6498 - root_mean_squared_error: 0.8061
# Epoch 114/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5206 - root_mean_squared_error: 0.7215
# Epoch 115/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9736 - root_mean_squared_error: 0.9867
# Epoch 116/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0029 - root_mean_squared_error: 1.0015
# Epoch 117/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8694 - root_mean_squared_error: 0.9324
# Epoch 118/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2279 - root_mean_squared_error: 1.1081
# Epoch 119/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.9872 - root_mean_squared_error: 0.9936
# Epoch 120/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7997 - root_mean_squared_error: 0.8943
# Epoch 121/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6617 - root_mean_squared_error: 0.8135
# Epoch 122/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8183 - root_mean_squared_error: 0.9046
# Epoch 123/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7366 - root_mean_squared_error: 0.8582
# Epoch 124/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5967 - root_mean_squared_error: 0.7725
# Epoch 125/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7737 - root_mean_squared_error: 0.8796
# Epoch 126/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5091 - root_mean_squared_error: 0.7135
# Epoch 127/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5919 - root_mean_squared_error: 0.7693
# Epoch 128/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7068 - root_mean_squared_error: 0.8407
# Epoch 129/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8866 - root_mean_squared_error: 0.9416
# Epoch 130/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7426 - root_mean_squared_error: 0.8618
# Epoch 131/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8216 - root_mean_squared_error: 0.9064
# Epoch 132/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5392 - root_mean_squared_error: 0.7343
# Epoch 133/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5630 - root_mean_squared_error: 0.7503
# Epoch 134/200
# 12/12 [==============================] - 0s 11ms/step - loss: 1.0411 - root_mean_squared_error: 1.0203
# Epoch 135/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7762 - root_mean_squared_error: 0.8810
# Epoch 136/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.4836 - root_mean_squared_error: 1.2180
# Epoch 137/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0906 - root_mean_squared_error: 1.0443
# Epoch 138/200
# 12/12 [==============================] - 0s 13ms/step - loss: 1.7038 - root_mean_squared_error: 1.3053
# Epoch 139/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1134 - root_mean_squared_error: 1.0552
# Epoch 140/200
# 12/12 [==============================] - 0s 14ms/step - loss: 1.9617 - root_mean_squared_error: 1.4006
# Epoch 141/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6833 - root_mean_squared_error: 0.8266
# Epoch 142/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.1918 - root_mean_squared_error: 1.0917
# Epoch 143/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.8451 - root_mean_squared_error: 0.9193
# Epoch 144/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.9549 - root_mean_squared_error: 0.9772
# Epoch 145/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8528 - root_mean_squared_error: 0.9235
# Epoch 146/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8267 - root_mean_squared_error: 0.9092
# Epoch 147/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1407 - root_mean_squared_error: 1.0681
# Epoch 148/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.1336 - root_mean_squared_error: 1.0647
# Epoch 149/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8696 - root_mean_squared_error: 0.9325
# Epoch 150/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6898 - root_mean_squared_error: 0.8305
# Epoch 151/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8023 - root_mean_squared_error: 0.8957
# Epoch 152/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7398 - root_mean_squared_error: 0.8601
# Epoch 153/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5599 - root_mean_squared_error: 0.7483
# Epoch 154/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8410 - root_mean_squared_error: 0.9171
# Epoch 155/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8169 - root_mean_squared_error: 0.9038
# Epoch 156/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2447 - root_mean_squared_error: 1.1156
# Epoch 157/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8865 - root_mean_squared_error: 0.9415
# Epoch 158/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8458 - root_mean_squared_error: 0.9197
# Epoch 159/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6713 - root_mean_squared_error: 0.8193
# Epoch 160/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5030 - root_mean_squared_error: 0.7093
# Epoch 161/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7214 - root_mean_squared_error: 0.8493
# Epoch 162/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.1076 - root_mean_squared_error: 1.0524
# Epoch 163/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9105 - root_mean_squared_error: 0.9542
# Epoch 164/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7374 - root_mean_squared_error: 0.8587
# Epoch 165/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4541 - root_mean_squared_error: 0.6739
# Epoch 166/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4748 - root_mean_squared_error: 0.6890
# Epoch 167/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6068 - root_mean_squared_error: 0.7790
# Epoch 168/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6537 - root_mean_squared_error: 0.8085
# Epoch 169/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5729 - root_mean_squared_error: 0.7569
# Epoch 170/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4643 - root_mean_squared_error: 0.6814
# Epoch 171/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6287 - root_mean_squared_error: 0.7929
# Epoch 172/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6332 - root_mean_squared_error: 0.7957
# Epoch 173/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7371 - root_mean_squared_error: 0.8585
# Epoch 174/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7816 - root_mean_squared_error: 0.8841
# Epoch 175/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6068 - root_mean_squared_error: 0.7789
# Epoch 176/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8588 - root_mean_squared_error: 0.9267
# Epoch 177/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6853 - root_mean_squared_error: 0.8279
# Epoch 178/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7583 - root_mean_squared_error: 0.8708
# Epoch 179/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9418 - root_mean_squared_error: 0.9705
# Epoch 180/200
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4450 - root_mean_squared_error: 1.2021
# Epoch 181/200
# 12/12 [==============================] - 0s 10ms/step - loss: 3.0233 - root_mean_squared_error: 1.7388
# Epoch 182/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.5946 - root_mean_squared_error: 1.2628
# Epoch 183/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8206 - root_mean_squared_error: 0.9059
# Epoch 184/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4864 - root_mean_squared_error: 0.6974
# Epoch 185/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3626 - root_mean_squared_error: 0.6022
# Epoch 186/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2493 - root_mean_squared_error: 0.4993
# Epoch 187/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3134 - root_mean_squared_error: 0.5599
# Epoch 188/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5376 - root_mean_squared_error: 0.7332
# Epoch 189/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2811 - root_mean_squared_error: 0.5302
# Epoch 190/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3429 - root_mean_squared_error: 0.5856
# Epoch 191/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3712 - root_mean_squared_error: 0.6093
# Epoch 192/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6650 - root_mean_squared_error: 0.8155
# Epoch 193/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7851 - root_mean_squared_error: 0.8860
# Epoch 194/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6630 - root_mean_squared_error: 0.8143
# Epoch 195/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6711 - root_mean_squared_error: 0.8192
# Epoch 196/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.1187 - root_mean_squared_error: 1.0577
# Epoch 197/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3747 - root_mean_squared_error: 1.1725
# Epoch 198/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3999 - root_mean_squared_error: 1.5491
# Epoch 199/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4436 - root_mean_squared_error: 1.2015
# Epoch 200/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8971 - root_mean_squared_error: 1.3773

# %%
predicted_stock_prices= lstm.predict(X_test)

print(X_test.shape)
print(y_test.shape)

plt.plot(y_test, color = 'red', label = 'Actual Stock Price')
plt.plot(predicted_stock_prices, color = 'green', label = 'Predicted Stock Price')
plt.title(random_company_code + ' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()


#TPSE, UMME  giving the best results .
# Out:
# 1/1 [==============================] - 1s 1s/step
# (9, 1, 5)
# (9,)

# %%
test_df = pd.DataFrame(data={'Actual Stock Prices':y_test.flatten(),'Predicted Stock Prices':predicted_stock_prices.flatten()})
test_df
# Out:
#    Actual Stock Prices  Predicted Stock Prices
# 0                14.85               12.736723
# 1                14.85               12.736723
# 2                14.85               12.736717
# 3                14.85               12.736723
# 4                14.00               12.698060
# 5                14.00               12.541132
# 6                14.00               12.541132
# 7                14.00               12.541132
# 8                14.00               12.541132
